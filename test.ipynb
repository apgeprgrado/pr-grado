# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
path_train = "train\Closed"

# %%
labels = os.listdir(path_train)
labels
# Out:
# ['_0.jpg',
#  '_1.jpg',
#  '_10.jpg',
#  '_100.jpg',
#  '_101.jpg',
#  '_102.jpg',
#  '_103.jpg',
#  '_104.jpg',
#  '_105.jpg',
#  '_106.jpg',
#  '_107.jpg',
#  '_108.jpg',
#  '_109.jpg',
#  '_11.jpg',
#  '_110.jpg',
#  '_111.jpg',
#  '_112.jpg',
#  '_113.jpg',
#  '_114.jpg',
#  '_115.jpg',
#  '_116.jpg',
#  '_117.jpg',
#  '_118.jpg',
#  '_119.jpg',
#  '_12.jpg',
#  '_120.jpg',
#  '_121.jpg',
#  '_122.jpg',
#  '_123.jpg',
#  '_124.jpg',
#  '_125.jpg',
#  '_126.jpg',
#  '_127.jpg',
#  '_128.jpg',
#  '_129.jpg',
#  '_13.jpg',
#  '_130.jpg',
#  '_131.jpg',
#  '_132.jpg',
#  '_133.jpg',
#  '_134.jpg',
#  '_135.jpg',
#  '_136.jpg',
#  '_137.jpg',
#  '_138.jpg',
#  '_139.jpg',
#  '_14.jpg',
#  '_140.jpg',
#  '_141.jpg',
#  '_142.jpg',
#  '_143.jpg',
#  '_144.jpg',
#  '_145.jpg',
#  '_146.jpg',
#  '_147.jpg',
#  '_148.jpg',
#  '_149.jpg',
#  '_15.jpg',
#  '_150.jpg',
#  '_151.jpg',
#  '_152.jpg',
#  '_153.jpg',
#  '_154.jpg',
#  '_155.jpg',
#  '_156.jpg',
#  '_157.jpg',
#  '_158.jpg',
# ...

# %%
a = plt.imread(path_train+"/_0.jpg")
a.shape
# Out:
# (145, 145, 3)

# %%
image = mpimg.imread(path_train+"/_0.jpg")
plt.imshow(image)
plt.show()
